# %% [markdown]
# ### Table of Contents
# * [1) Pengumpulan Data](#h1)
# * [2) Menelaah Data](#h2)
# * [3) Validasi Data](#h3)
# * [4) Menetukan Object Data](#h4)
# * [5) Membersihkan Data](#h5)
# * [6) Konstruksi Data](#h6)
# * [7) Menentukan label data](#h7)
# * [8) Modelling](#h8)
# * [9) Evaluasi](#h9)

# %% [markdown]
# ## 1) Pengumpulan Data <a class="anchor" id="h1"></a>

# %% [markdown]
# references : https://www.kaggle.com/datasets/aadarshvelu/aids-virus-infection-prediction

# %% [markdown]
# ## 2) Menelaah Data <a class="anchor" id="h2"></a>

# %%
import numpy as np # untuk komputasi numerik (matematika, array, statistik).
import pandas as pd # untuk manipulasi dan analisis data dalam format tabel.


# Menampilkan semua kolom dari dataframe saat mencetak dataframe
pd.set_option("display.max_columns", None)

# %% [markdown]
# ### Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Mengecek file dalam directory
# !ls "/content/drive/MyDrive/BK-DS/03_AIDS/dataset/AIDS_dirty.csv"
# Out:
# /content/drive/MyDrive/BK-DS/03_AIDS/dataset/AIDS_dirty.csv

# %%
# dir adalah variabel yang digunakan untuk menyimpan data dengan path yang ada google drive
dir =  '/content/drive/MyDrive/BK-DS/03_AIDS/dataset/AIDS_dirty.csv'

# %% [markdown]
# Baca dataset csv dengan library pandas

# %%
# Membaca dan menampilkan dataset
data = pd.read_csv(dir) # membaca file CSV dari path yang telah didefinisikan sebelumnya.
data.head()
# Out:
#    time  trt   age     wtkg  hemo  homo  drugs  karnof  oprior  z30  preanti  \
# 0   948    2  48.0  89.8128     0     0      0     100       0    0        0
# 1  1002    3  61.0  49.4424     0     0      0      90       0    1      895
# 2   961    3  45.0  88.4520     0     1      1      90       0    1      707
# 3  1166    3  47.0  85.2768     0     1      0     100       0    1     1399
# 4  1090    0  43.0  66.6792     0     1      0     100       0    1     1352
#
#    race  gender  str2  strat  symptom  treat  offtrt   cd40  cd420  cd80  \
# 0     0       0     0      1        0      1       0  422.0    477   566
# 1     0       0     1      3        0      1       0  162.0    218   392
# 2     0       1     1      3        0      1       1  326.0    274  2063
# 3     0       1     1      3        0      1       0  287.0    394  1590
# 4     0       1     1      3        0      0       0  504.0    353   870
#
#    cd820  infected
# 0    324         0
# 1    564         1
# 2   1893         0
# 3    966         0
# 4    782         0

# %%
data
# Out:
#       time  trt    age     wtkg  hemo  homo  drugs  karnof  oprior  z30  \
# 0      948    2   48.0  89.8128     0     0      0     100       0    0
# 1     1002    3   61.0  49.4424     0     0      0      90       0    1
# 2      961    3   45.0  88.4520     0     1      1      90       0    1
# 3     1166    3   47.0  85.2768     0     1      0     100       0    1
# 4     1090    0   43.0  66.6792     0     1      0     100       0    1
# ...    ...  ...    ...      ...   ...   ...    ...     ...     ...  ...
# 2241   987    1  150.0  67.8132     0     1      0     100       0    0
# 2242  1126    3  150.0  78.4728     0     1      0     100       0    1
# 2243   373    2   31.0  75.2976     0     1      0     100       0    1
# 2244  1081    1   40.0  70.0812     0     0      1      80       0    0
# 2245   824    1   40.0  68.0400     0     1      0     100       0    0
#
#       preanti  race  gender  str2  strat  symptom  treat  offtrt   cd40  \
# 0           0     0       0     0      1        0      1       0  422.0
# 1         895     0       0     1      3        0      1       0  162.0
# 2         707     0       1     1      3        0      1       1  326.0
# 3        1399     0       1     1      3        0      1       0  287.0
# 4        1352     0       1     1      3        0      0       0  504.0
# ...       ...   ...     ...   ...    ...      ...    ...     ...    ...
# 2241       65     0       1     1      2        0      1       1  320.0
# 2242      967     0       1     1      3        0      1       0  365.0
# 2243     1538     0       1     1      3        1      1       1  344.0
# 2244        0     0       0     0      1        0      1       1  400.0
# 2245        0     1       1     0      1        0      1       1  477.0
#
#       cd420  cd80  cd820  infected
# 0       477   566    324         0
# 1       218   392    564         1
# 2       274  2063   1893         0
# 3       394  1590    966         0
# 4       353   870    782         0
# ...     ...   ...    ...       ...
# 2241    320  1860   1290         0
# 2242    265  1964   1546         0
# 2243    291  1607   1543         1
# 2244    550  1250   1020         0
# 2245    566   542    616         0
#
# [2246 rows x 23 columns]

# %%
data.tail() # Menampilkan data 5 baris terakhir dataset.
# Out:
#       time  trt    age     wtkg  hemo  homo  drugs  karnof  oprior  z30  \
# 2241   987    1  150.0  67.8132     0     1      0     100       0    0
# 2242  1126    3  150.0  78.4728     0     1      0     100       0    1
# 2243   373    2   31.0  75.2976     0     1      0     100       0    1
# 2244  1081    1   40.0  70.0812     0     0      1      80       0    0
# 2245   824    1   40.0  68.0400     0     1      0     100       0    0
#
#       preanti  race  gender  str2  strat  symptom  treat  offtrt   cd40  \
# 2241       65     0       1     1      2        0      1       1  320.0
# 2242      967     0       1     1      3        0      1       0  365.0
# 2243     1538     0       1     1      3        1      1       1  344.0
# 2244        0     0       0     0      1        0      1       1  400.0
# 2245        0     1       1     0      1        0      1       1  477.0
#
#       cd420  cd80  cd820  infected
# 2241    320  1860   1290         0
# 2242    265  1964   1546         0
# 2243    291  1607   1543         1
# 2244    550  1250   1020         0
# 2245    566   542    616         0

# %% [markdown]
# menampilan informasi dari file dataset yang sudah dimasukkan kedalam dataframe

# %%
# Informasi dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2246 entries, 0 to 2245
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      2246 non-null   int64
#  1   trt       2246 non-null   int64
#  2   age       2140 non-null   float64
#  3   wtkg      2246 non-null   float64
#  4   hemo      2246 non-null   int64
#  5   homo      2246 non-null   int64
#  6   drugs     2246 non-null   int64
#  7   karnof    2246 non-null   int64
#  8   oprior    2246 non-null   int64
#  9   z30       2246 non-null   int64
#  10  preanti   2246 non-null   int64
#  11  race      2246 non-null   int64
#  12  gender    2246 non-null   int64
#  13  str2      2246 non-null   int64
#  14  strat     2246 non-null   int64
#  15  symptom   2246 non-null   int64
#  16  treat     2246 non-null   int64
#  17  offtrt    2246 non-null   int64
#  18  cd40      2025 non-null   float64
#  19  cd420     2246 non-null   int64
#  20  cd80      2246 non-null   int64
#  21  cd820     2246 non-null   int64
#  22  infected  2246 non-null   int64
# dtypes: float64(3), int64(20)
# memory usage: 403.7 KB

# %%
data.describe().T # memberikan statistik deskriptif dataset (mean, std, min, dll.) dan ditranspos (T) agar lebih mudah dibaca
# Out:
#            count        mean         std    min       25%       50%  \
# time      2246.0  879.661621  291.643124   14.0  728.2500  997.0000
# trt       2246.0   51.266251  217.170267    0.0    1.0000    2.0000
# age       2140.0   39.268692   28.671949   -5.0   29.0000   34.0000
# wtkg      2246.0   90.307937   91.330706    0.1   65.3184   74.1318
# hemo      2246.0    0.081923    0.274309    0.0    0.0000    0.0000
# homo      2246.0    0.662066    0.473111    0.0    0.0000    1.0000
# drugs     2246.0    0.132680    0.339304    0.0    0.0000    0.0000
# karnof    2246.0   95.454141    5.912758   70.0   90.0000  100.0000
# oprior    2246.0    0.022262    0.147567    0.0    0.0000    0.0000
# z30       2246.0    0.548085    0.497793    0.0    0.0000    1.0000
# preanti   2246.0  375.873108  467.750573    0.0    0.0000  139.0000
# race      2246.0    0.290294    0.453999    0.0    0.0000    0.0000
# gender    2246.0    0.827694    0.377731    0.0    1.0000    1.0000
# str2      2246.0    0.583704    0.493054    0.0    0.0000    1.0000
# strat     2246.0    1.974176    0.898031    1.0    1.0000    2.0000
# symptom   2246.0    0.172306    0.377731    0.0    0.0000    0.0000
# treat     2246.0    0.749777    0.433238    0.0    0.2500    1.0000
# offtrt    2246.0    0.363313    0.481061    0.0    0.0000    0.0000
# cd40      2025.0  351.157531  118.676756    0.0  264.0000  340.0000
# cd420     2246.0  371.170525  144.612361   49.0  269.0000  353.5000
# cd80      2246.0  990.337489  480.363433   40.0  657.2500  895.0000
# cd820     2246.0  937.599288  444.902164  124.0  633.0000  871.0000
# infected  2246.0    0.243544    0.429316    0.0    0.0000    0.0000
#
#                 75%     max
# time      1090.0000  1231.0
# trt          3.0000   999.0
# age         41.0000   150.0
# wtkg        83.4468   500.0
# hemo         0.0000     1.0
# homo         1.0000     1.0
# drugs        0.0000     1.0
# karnof     100.0000   100.0
# oprior       0.0000     1.0
# z30          1.0000     1.0
# preanti    732.7500  2851.0
# race         1.0000     1.0
# gender       1.0000     1.0
# str2         1.0000     1.0
# strat        3.0000     3.0
# symptom      0.0000     1.0
# treat        1.0000     1.0
# offtrt       1.0000     1.0
# cd40       426.0000  1199.0
# cd420      460.0000  1119.0
# cd80      1210.0000  5011.0
# cd820     1146.7500  6035.0
# infected     0.0000     1.0

# %% [markdown]
# ## 3) Validasi Data <a class="anchor" id="h3"></a>

# %% [markdown]
# Pada tahap ini bertujuan untuk mengetahui dan memahami isi dari dataset agar dapat dilakukan penanganan sesuai dengan kondisinya.

# %%
import matplotlib.pyplot as plt # visualisasi data (grafik dasar seperti garis, batang).
import seaborn as sns # visualisasi statistik yang lebih menarik dan informatif.

# %% [markdown]
# Membuat fungsi untuk memecah variable kategori dan numerik

# %%
# Mengidentifikasi jenis kolom (variabel) dalam sebuah dataframe berdasarkan tipe data dan karakteristiknya

def grab_col_names(dataframe, cat_th = 10, car_th = 20): #  memisahkan kolom dalam dataset berdasarkan tipe dan karakteristiknya.

    cat_cols = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["category", "object", "bool"]] # kolom kategorikal (tipe "category", "object", "bool", atau numerik dengan unique values < cat_th).
    num_but_cat = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["int64", "float64"] and dataframe[col].nunique() < cat_th] # kolom numerik yang bertindak seperti kategorikal (berdasarkan jumlah unique values).
    cat_but_car = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["category", "object"] and dataframe[col].nunique() > car_th] # kolom kategorikal dengan unique values > car_th (high cardinality).

    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    # kolom numerik murni (int64, float64) yang bukan kategorikal.
    num_cols = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["int64", "float64"]]
    num_cols = [col for col in num_cols if col not in cat_cols]

    print(f"Jumlah observasi: {dataframe.shape[0]}")
    print(f"Jumlah variabel: {dataframe.shape[1]}")
    print(f"Kolom kategorikal: {len(cat_cols)}")
    print(f"Kolom Numerik: {len(num_cols)}")
    print(f"Kategori tapi kardinal: {len(cat_but_car)}")
    print(f"Numerik tapi kategorikal: {len(num_but_cat)}")

    # mengembalikan daftar kolom yang dikelompokkan berdasarkan tipe (cat_cols, num_cols, cat_but_car).
    return cat_cols, num_cols, cat_but_car

# %% [markdown]
# Membuat fungsi untuk menampilkan visual berdasarkan variabel kategori

# %%
def plot_categorical(dataframe, categorical_columns):

    # Jumlah kolom kategorikal
    num_cols = len(categorical_columns)
    # Kita membuat 2 subplot (countplot + pie plot) untuk setiap kolom
    fig, axes = plt.subplots(num_cols, 2, figsize=(17, 5 * num_cols))
    axes = axes.flatten()

    for i, col in enumerate(categorical_columns):
        # --- Bagian Countplot ---
        sns.countplot(
            x=col,
            data=dataframe,
            ax=axes[2*i],
            hue=col,
            palette="rocket"
        )
        axes[2*i].set_title(f'{col} Count', fontsize=12)
        axes[2*i].set_xlabel(col)
        axes[2*i].set_ylabel('Count')

        # --- Bagian Pie Plot ---
        # Menentukan jumlah kategori unik
        unique_vals = dataframe[col].nunique()
        # Membuat list warna sesuai banyaknya kategori unik
        pie_colors = sns.color_palette("rocket", unique_vals)

        dataframe[col].value_counts().plot.pie(
            autopct='%1.1f%%',
            ax=axes[2*i + 1],
            colors=pie_colors
        )
        axes[2*i+1].set_title(f'{col} Distribution', fontsize=12)
        axes[2*i+1].set_ylabel('')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Analisa variabel numerik

# %%
#Membuat histogram untuk setiap kolom numerik dalam dataframe

def plot_histograms(dataframe, numeric_columns):
    sns.set_theme(style="whitegrid")

    # Hitung jumlah kolom numerik dan tentukan jumlah baris subplot
    num_cols = len(numeric_columns)
    num_rows = (num_cols + 1) // 4 + ((num_cols + 1) % 4 != 0)
    fig, axes = plt.subplots(num_rows, 4, figsize=(20, 5 * num_rows))
    axes = axes.flatten()


    color = "#3bb4cf"

    for i, col in enumerate(numeric_columns):
        dataframe[col].hist(ax=axes[i], bins=20, color=color)
        axes[i].set_title(col, fontsize=12)
        axes[i].set_xlabel(col, fontsize=10)
        axes[i].set_ylabel('Frequency', fontsize=10)

    # Hapus sumbu yang tidak terpakai jika jumlah kolom tidak habis dibagi 4
    for j in range(num_cols, num_rows * 4):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
# Menganalisis hubungan antara kolom kategorikal dengan target (variabel dependen) dalam sebuah dataframe, dan menyajikan hasilnya dalam bentuk tabel dan visualisasi bar chart
def target_summary_with_cat_visualized(dataframe, target, categorical_col):
    # Rata-rata nilai target dihitung untuk setiap kategori
    grouped_data = dataframe.groupby(categorical_col)[target].mean()

    # Membuat DataFrame dari hasil pengelompokan
    summary_df = pd.DataFrame({"TARGET_MEAN": grouped_data})

    # Visualisasi dengan Bar Chart
    plt.figure(figsize=(5, 5))
    summary_df.plot(kind='bar', color="#f180a7", legend=False)
    plt.title('Mean Target by ' + categorical_col)
    plt.xlabel(categorical_col)
    plt.ylabel('Mean Target')
    plt.xticks(rotation=1)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    # Menampilkan tabel ringkasan
    print(pd.DataFrame({"TARGET_MEAN": dataframe.groupby(categorical_col)[target].mean()}))
    print("-" * 50)

# %% [markdown]
# Target analisa variabel degnan variabel numerik

# %%
# Menganalisis hubungan antara kolom target (kategorikal) dengan kolom numerik dalam sebuah dataframe
def target_summary_with_num_visualized(dataframe, target, numerical_col):
    # Hitung rata-rata dari kolom numerik untuk setiap kategori variabel target
    grouped_data = dataframe.groupby(target)[numerical_col].mean()

    # Membuat diagram batang untuk memvisualisasikan data
    plt.figure(figsize=(5, 5))
    grouped_data.plot(kind='bar', color='#ffd8ad')
    plt.title('Mean ' + numerical_col + ' by ' + target)
    plt.xlabel(target)
    plt.ylabel('Mean ' + numerical_col)
    plt.xticks(rotation=1)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    print(dataframe.groupby(target).agg({numerical_col: "mean"}))
    print("-"*50)

# %% [markdown]
# Analisa Outlier untuk mengetahui data yang tidak sesuai

# %%
# Membuat visualisasi boxplot (diagram kotak) untuk semua kolom numerik yang diberikan
def boxplot(dataframe, numeric_columns):
    num_plots = len(numeric_columns)
    num_rows = (num_plots + 3) // 4  # Menghitung jumlah baris grafik
    fig, axes = plt.subplots(num_rows, 4, figsize=(18, 4 * num_rows))  # Membuat grid subplot
    axes = axes.flatten()

    for i, column in enumerate(numeric_columns):
        sns.boxplot(y=dataframe[column], ax=axes[i], color="#cc3569")
        axes[i].set_title(f'Boxplot of {column}')
        axes[i].set_ylabel(column)

    # Hapus subplot yang tidak terpakai
    for j in range(num_plots, num_rows * 4):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
# Memanggil fungsi grab_col_names yang telah didefinisikan untuk memisahkan kolom-kolom dalam dataframe menjadi tiga kategori berdasarkan tipe data dan karakteristik distribusinya
cat_cols, num_cols, cat_but_car = grab_col_names(data)
# Out:
# Jumlah observasi: 2246
# Jumlah variabel: 23
# Kolom kategorikal: 15
# Kolom Numerik: 8
# Kategori tapi kardinal: 0
# Numerik tapi kategorikal: 15

# %%
plot_categorical(data, cat_cols)

# %%
plot_histograms(data, num_cols)

# %%
for col in cat_cols:
    target_summary_with_cat_visualized(data, "infected", col)
# Out:
#      TARGET_MEAN
# trt
# 0       0.333973
# 1       0.195446
# 2       0.204159
# 3       0.240575
# 999     0.250000
# --------------------------------------------------
#       TARGET_MEAN
# hemo
# 0        0.244423
# 1        0.233696
# --------------------------------------------------
#       TARGET_MEAN
# homo
# 0        0.210804
# 1        0.260256
# --------------------------------------------------
#        TARGET_MEAN
# drugs
# 0         0.253080
# 1         0.181208
# --------------------------------------------------
#         TARGET_MEAN
# karnof
# 70         0.400000
# 80         0.357143
# 90         0.280680
# 100        0.212190
# --------------------------------------------------
#         TARGET_MEAN
# oprior
# 0          0.241348
# 1          0.340000
# --------------------------------------------------
#      TARGET_MEAN
# z30
# 0       0.182266
# 1       0.294070
# --------------------------------------------------
#       TARGET_MEAN
# race
# 0        0.257842
# 1        0.208589
# --------------------------------------------------
#         TARGET_MEAN
# gender
# 0          0.204134
# 1          0.251748
# --------------------------------------------------
#       TARGET_MEAN
# str2
# 0        0.177540
# 1        0.290618
# --------------------------------------------------
#        TARGET_MEAN
# strat
# 1         0.177540
# 2         0.255760
# 3         0.307868
# --------------------------------------------------
#          TARGET_MEAN
# symptom
# 0           0.218397
# 1           0.364341
# --------------------------------------------------
#        TARGET_MEAN
# treat
# 0         0.334520
# 1         0.213183
# --------------------------------------------------
#         TARGET_MEAN
# offtrt
# 0          0.213986
# 1          0.295343
# --------------------------------------------------
#           TARGET_MEAN
# infected
# 0                 0.0
# 1                 1.0
# --------------------------------------------------

# %%
for col in num_cols:
    target_summary_with_num_visualized(data, "infected", col)
# Out:
#                 time
# infected
# 0         974.583873
# 1         584.829982
# --------------------------------------------------
#                 age
# infected
# 0         39.208256
# 1         39.458414
# --------------------------------------------------
#                wtkg
# infected
# 0         91.229011
# 1         87.447050
# --------------------------------------------------
#              preanti
# infected
# 0         340.443202
# 1         485.919561
# --------------------------------------------------
#                 cd40
# infected
# 0         364.238251
# 1         310.509128
# --------------------------------------------------
#                cd420
# infected
# 0         399.325486
# 1         283.720293
# --------------------------------------------------
#                  cd80
# infected
# 0          973.293114
# 1         1043.277879
# --------------------------------------------------
#                cd820
# infected
# 0         933.848146
# 1         949.250457
# --------------------------------------------------

# %%
boxplot(data, num_cols)

# %% [markdown]
# Pada tahap validasi bertujuan untuk mengetahui dan memahami isi dari dataset agar dapat dilakukan penanganan sesuai dengan kondisinya. Membuat fungsi-fungsi yang dibutuhkan, lalu melakukan pemanggilan. Diantaranya ada, mengidentifikasi jenis kolom (variabel) dalam sebuah dataframe berdasarkan tipe data dan karakteristiknya, memvisualisasikan distribusi kolom-kolom kategorikal dalam sebuah dataframe menggunakan dua jenis plot: countplot dan pie plot, membuat histogram bagi setiap kolom numerik dalam sebuah dataframe, menganalisis hubungan antara kolom kategorikal dengan target (variabel dependen) dalam sebuah dataframe, dan menyajikan hasilnya dalam bentuk tabel dan visualisasi bar chart, menganalisis hubungan antara kolom target (kategorikal) dengan kolom numerik dalam sebuah dataframe, membuat visualisasi boxplot (diagram kotak) untuk semua kolom numerik yang diberikan.

# %% [markdown]
# ## 4) Menentukan Object Data <a class="anchor" id="h4"></a>

# %%
# Menampilkan 5 baris pertama dari dataframe data
data.head()
# Out:
#    time  trt   age     wtkg  hemo  homo  drugs  karnof  oprior  z30  preanti  \
# 0   948    2  48.0  89.8128     0     0      0     100       0    0        0
# 1  1002    3  61.0  49.4424     0     0      0      90       0    1      895
# 2   961    3  45.0  88.4520     0     1      1      90       0    1      707
# 3  1166    3  47.0  85.2768     0     1      0     100       0    1     1399
# 4  1090    0  43.0  66.6792     0     1      0     100       0    1     1352
#
#    race  gender  str2  strat  symptom  treat  offtrt   cd40  cd420  cd80  \
# 0     0       0     0      1        0      1       0  422.0    477   566
# 1     0       0     1      3        0      1       0  162.0    218   392
# 2     0       1     1      3        0      1       1  326.0    274  2063
# 3     0       1     1      3        0      1       0  287.0    394  1590
# 4     0       1     1      3        0      0       0  504.0    353   870
#
#    cd820  infected
# 0    324         0
# 1    564         1
# 2   1893         0
# 3    966         0
# 4    782         0

# %%
# Menampilkan 5 baris terakhir dari dataframe data
data.tail()
# Out:
#       time  trt    age     wtkg  hemo  homo  drugs  karnof  oprior  z30  \
# 2241   987    1  150.0  67.8132     0     1      0     100       0    0
# 2242  1126    3  150.0  78.4728     0     1      0     100       0    1
# 2243   373    2   31.0  75.2976     0     1      0     100       0    1
# 2244  1081    1   40.0  70.0812     0     0      1      80       0    0
# 2245   824    1   40.0  68.0400     0     1      0     100       0    0
#
#       preanti  race  gender  str2  strat  symptom  treat  offtrt   cd40  \
# 2241       65     0       1     1      2        0      1       1  320.0
# 2242      967     0       1     1      3        0      1       0  365.0
# 2243     1538     0       1     1      3        1      1       1  344.0
# 2244        0     0       0     0      1        0      1       1  400.0
# 2245        0     1       1     0      1        0      1       1  477.0
#
#       cd420  cd80  cd820  infected
# 2241    320  1860   1290         0
# 2242    265  1964   1546         0
# 2243    291  1607   1543         1
# 2244    550  1250   1020         0
# 2245    566   542    616         0

# %%
# Menampilkan informasi ringkas tentang dataframe data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2246 entries, 0 to 2245
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      2246 non-null   int64
#  1   trt       2246 non-null   int64
#  2   age       2140 non-null   float64
#  3   wtkg      2246 non-null   float64
#  4   hemo      2246 non-null   int64
#  5   homo      2246 non-null   int64
#  6   drugs     2246 non-null   int64
#  7   karnof    2246 non-null   int64
#  8   oprior    2246 non-null   int64
#  9   z30       2246 non-null   int64
#  10  preanti   2246 non-null   int64
#  11  race      2246 non-null   int64
#  12  gender    2246 non-null   int64
#  13  str2      2246 non-null   int64
#  14  strat     2246 non-null   int64
#  15  symptom   2246 non-null   int64
#  16  treat     2246 non-null   int64
#  17  offtrt    2246 non-null   int64
#  18  cd40      2025 non-null   float64
#  19  cd420     2246 non-null   int64
#  20  cd80      2246 non-null   int64
#  21  cd820     2246 non-null   int64
#  22  infected  2246 non-null   int64
# dtypes: float64(3), int64(20)
# memory usage: 403.7 KB

# %% [markdown]
# menghitung jumlah fitur pada dataset

# %%
# Menghitung frekuensi kemunculan nilai unik dalam sebuah kolom atau objek Pandas
data.value_counts()

# %% [markdown]
# ## 5) Membersihkan Data <a class="anchor" id="h5"></a>

# %%
data.isnull().sum()
# Out:
# time          0
# trt           0
# age         106
# wtkg          0
# hemo          0
# homo          0
# drugs         0
# karnof        0
# oprior        0
# z30           0
# preanti       0
# race          0
# gender        0
# str2          0
# strat         0
# symptom       0
# treat         0
# offtrt        0
# cd40        221
# cd420         0
# cd80          0
# cd820         0
# infected      0
# dtype: int64

# %%
# Mendeteksi keberadaan nilai Null
data.loc[:, data.isnull().any()].columns
# Out:
# Index(['age', 'cd40'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2246 entries, 0 to 2245
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      2246 non-null   int64
#  1   trt       2246 non-null   int64
#  2   age       2140 non-null   float64
#  3   wtkg      2246 non-null   float64
#  4   hemo      2246 non-null   int64
#  5   homo      2246 non-null   int64
#  6   drugs     2246 non-null   int64
#  7   karnof    2246 non-null   int64
#  8   oprior    2246 non-null   int64
#  9   z30       2246 non-null   int64
#  10  preanti   2246 non-null   int64
#  11  race      2246 non-null   int64
#  12  gender    2246 non-null   int64
#  13  str2      2246 non-null   int64
#  14  strat     2246 non-null   int64
#  15  symptom   2246 non-null   int64
#  16  treat     2246 non-null   int64
#  17  offtrt    2246 non-null   int64
#  18  cd40      2025 non-null   float64
#  19  cd420     2246 non-null   int64
#  20  cd80      2246 non-null   int64
#  21  cd820     2246 non-null   int64
#  22  infected  2246 non-null   int64
# dtypes: float64(3), int64(20)
# memory usage: 403.7 KB

# %%
# Mengonversi kolom 'age' dan 'cd40' dari float64 ke int
data['age'] = data['age'].fillna(0).astype(int)  # Menangani NaN dengan mengisinya dengan 0 (bisa diubah sesuai kebutuhan)
data['cd40'] = data['cd40'].fillna(0).astype(int)  # kolom 'cd40'

# Menampilkan tipe data kolom setelah konversi
print(data.dtypes)
# Out:
# time          int64
# trt           int64
# age           int64
# wtkg        float64
# hemo          int64
# homo          int64
# drugs         int64
# karnof        int64
# oprior        int64
# z30           int64
# preanti       int64
# race          int64
# gender        int64
# str2          int64
# strat         int64
# symptom       int64
# treat         int64
# offtrt        int64
# cd40          int64
# cd420         int64
# cd80          int64
# cd820         int64
# infected      int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# time        0
# trt         0
# age         0
# wtkg        0
# hemo        0
# homo        0
# drugs       0
# karnof      0
# oprior      0
# z30         0
# preanti     0
# race        0
# gender      0
# str2        0
# strat       0
# symptom     0
# treat       0
# offtrt      0
# cd40        0
# cd420       0
# cd80        0
# cd820       0
# infected    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 107

# %%
# Menampilkan data duplikat
duplicate_rows = data.duplicated()
print("All Duplicate Rows:")
data[data.duplicated(keep=False)]
# Out:
# All Duplicate Rows:
#       time  trt  age     wtkg  hemo  homo  drugs  karnof  oprior  z30  \
# 33    1206    3   37  73.0000     0     0      0     100       0    0
# 35    1074    1   38  87.0000     0     1      1      90       0    1
# 52    1089    3   39  77.5000     0     1      0      80       0    1
# 74    1214  999   48   0.1000     0     0      1     100       0    1
# 83    1138    2   28  58.6000     0     1      0     100       0    1
# ...    ...  ...  ...      ...   ...   ...    ...     ...     ...  ...
# 2241   987    1  150  67.8132     0     1      0     100       0    0
# 2242  1126    3  150  78.4728     0     1      0     100       0    1
# 2243   373    2   31  75.2976     0     1      0     100       0    1
# 2244  1081    1   40  70.0812     0     0      1      80       0    0
# 2245   824    1   40  68.0400     0     1      0     100       0    0
#
#       preanti  race  gender  str2  strat  symptom  treat  offtrt  cd40  cd420  \
# 33          0     1       0     0      1        0      1       0   342    293
# 35         67     0       1     1      2        1      1       1   496    465
# 52         35     0       1     1      2        0      1       0   293    260
# 74        163     1       1     1      2        0      0       0   430    390
# 83        890     0       1     1      3        0      1       0   470    590
# ...       ...   ...     ...   ...    ...      ...    ...     ...   ...    ...
# 2241       65     0       1     1      2        0      1       1   320    320
# 2242      967     0       1     1      3        0      1       0   365    265
# 2243     1538     0       1     1      3        1      1       1   344    291
# 2244        0     0       0     0      1        0      1       1   400    550
# 2245        0     1       1     0      1        0      1       1   477    566
#
#       cd80  cd820  infected
# 33    1459   1646         0
# 35    2127   2753         0
# 52     730    604         0
# 74    1370   1780         0
# 83    1080   1090         0
# ...    ...    ...       ...
# 2241  1860   1290         0
# 2242  1964   1546         0
# 2243  1607   1543         1
# 2244  1250   1020         0
# 2245   542    616         0
#
# [214 rows x 23 columns]

# %%
# Menghapus data duplikat, menyimpan data dalam variabel dfClean
data_clean = data.drop_duplicates()
print("All Duplicate Rows:")
data_clean[data_clean.duplicated(keep=False)]
# Out:
# All Duplicate Rows:
# Empty DataFrame
# Columns: [time, trt, age, wtkg, hemo, homo, drugs, karnof, oprior, z30, preanti, race, gender, str2, strat, symptom, treat, offtrt, cd40, cd420, cd80, cd820, infected]
# Index: []

# %% [markdown]
# ## 6) Konstruksi Data <a class="anchor" id="h6"></a>

# %%
# Memberikan informasi detail tentang struktur dataframe
data_clean.info() # data_clean sebagai dataset yang telah bersih
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2139 entries, 0 to 2138
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      2139 non-null   int64
#  1   trt       2139 non-null   int64
#  2   age       2139 non-null   int64
#  3   wtkg      2139 non-null   float64
#  4   hemo      2139 non-null   int64
#  5   homo      2139 non-null   int64
#  6   drugs     2139 non-null   int64
#  7   karnof    2139 non-null   int64
#  8   oprior    2139 non-null   int64
#  9   z30       2139 non-null   int64
#  10  preanti   2139 non-null   int64
#  11  race      2139 non-null   int64
#  12  gender    2139 non-null   int64
#  13  str2      2139 non-null   int64
#  14  strat     2139 non-null   int64
#  15  symptom   2139 non-null   int64
#  16  treat     2139 non-null   int64
#  17  offtrt    2139 non-null   int64
#  18  cd40      2139 non-null   int64
#  19  cd420     2139 non-null   int64
#  20  cd80      2139 non-null   int64
#  21  cd820     2139 non-null   int64
#  22  infected  2139 non-null   int64
# dtypes: float64(1), int64(22)
# memory usage: 401.1 KB

# %%
# Memberikan ringkasan statistik deskriptif dari kolom numerik
data_clean.describe()
# Out:
#               time          trt          age         wtkg         hemo  \
# count  2139.000000  2139.000000  2139.000000  2139.000000  2139.000000
# mean    879.098177    51.428237    37.334268    90.439055     0.084151
# std     292.274324   217.494958    29.278109    91.171807     0.277680
# min      14.000000     0.000000    -5.000000     0.100000     0.000000
# 25%     727.000000     1.000000    28.000000    65.318400     0.000000
# 50%     997.000000     2.000000    34.000000    74.390400     0.000000
# 75%    1091.000000     3.000000    41.000000    83.462400     0.000000
# max    1231.000000   999.000000   150.000000   500.000000     1.000000
#
#               homo        drugs       karnof       oprior          z30  \
# count  2139.000000  2139.000000  2139.000000  2139.000000  2139.000000
# mean      0.661057     0.131370    95.446470     0.021973     0.550257
# std       0.473461     0.337883     5.900985     0.146629     0.497584
# min       0.000000     0.000000    70.000000     0.000000     0.000000
# 25%       0.000000     0.000000    90.000000     0.000000     0.000000
# 50%       1.000000     0.000000   100.000000     0.000000     1.000000
# 75%       1.000000     0.000000   100.000000     0.000000     1.000000
# max       1.000000     1.000000   100.000000     1.000000     1.000000
#
#            preanti         race       gender         str2        strat  \
# count  2139.000000  2139.000000  2139.000000  2139.000000  2139.000000
# mean    379.175783     0.288453     0.827957     0.585788     1.979897
# std     468.657526     0.453149     0.377506     0.492701     0.899053
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       0.000000     0.000000     1.000000     0.000000     1.000000
# 50%     142.000000     0.000000     1.000000     1.000000     2.000000
# 75%     739.500000     1.000000     1.000000     1.000000     3.000000
# max    2851.000000     1.000000     1.000000     1.000000     3.000000
#
#            symptom        treat       offtrt         cd40        cd420  \
# count  2139.000000  2139.000000  2139.000000  2139.000000  2139.000000
# mean      0.172978     0.751286     0.362786   315.690042   371.307153
# std       0.378317     0.432369     0.480916   154.599651   144.634909
# min       0.000000     0.000000     0.000000     0.000000    49.000000
# 25%       0.000000     1.000000     0.000000   236.000000   269.000000
# 50%       0.000000     1.000000     0.000000   320.000000   353.000000
# 75%       0.000000     1.000000     1.000000   417.000000   460.000000
# max       1.000000     1.000000     1.000000  1199.000000  1119.000000
#
#               cd80        cd820     infected
# count  2139.000000  2139.000000  2139.000000
# mean    986.627396   935.369799     0.243572
# std     480.197750   444.976051     0.429338
# min      40.000000   124.000000     0.000000
# 25%     654.000000   631.500000     0.000000
# 50%     893.000000   865.000000     0.000000
# 75%    1207.000000  1146.500000     0.000000
# max    5011.000000  6035.000000     1.000000

# %%
# Menampilkan 5 baris pertama
data_clean.head(5)
# Out:
#    time  trt  age     wtkg  hemo  homo  drugs  karnof  oprior  z30  preanti  \
# 0   948    2   48  89.8128     0     0      0     100       0    0        0
# 1  1002    3   61  49.4424     0     0      0      90       0    1      895
# 2   961    3   45  88.4520     0     1      1      90       0    1      707
# 3  1166    3   47  85.2768     0     1      0     100       0    1     1399
# 4  1090    0   43  66.6792     0     1      0     100       0    1     1352
#
#    race  gender  str2  strat  symptom  treat  offtrt  cd40  cd420  cd80  \
# 0     0       0     0      1        0      1       0   422    477   566
# 1     0       0     1      3        0      1       0   162    218   392
# 2     0       1     1      3        0      1       1   326    274  2063
# 3     0       1     1      3        0      1       0   287    394  1590
# 4     0       1     1      3        0      0       0   504    353   870
#
#    cd820  infected
# 0    324         0
# 1    564         1
# 2   1893         0
# 3    966         0
# 4    782         0

# %%
# Menampilkan Korelasi antar Fitur
correlation_matrix = data.corr()

plt.figure(figsize=(22, 18))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)

plt.title('Correlation Matrix', fontsize=14)
plt.xticks(fontsize=10, rotation=90)
plt.yticks(fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7) Menentukan Label <a class="anchor" id="h7"></a>

# %%
# Memisahkan fitur (X) dan target (y) dalam dataset
X = data_clean.drop("infected", axis = 1)
y = data_clean["infected"]

# %%
# Membuat visualisasi berupa diagram batang (bar plot) yang menunjukkan jumlah individu yang termasuk dalam masing-masing kategori pada kolom infected
data_clean['infected'].value_counts().plot(kind='bar',figsize=(10,6),color=['#ac3664','#edce88'])
plt.title("Count of the infected person")
plt.xticks(rotation=0);

# %% [markdown]
# Pada Grafik diatas menunjukan bahwa persebaran jumlah target tidak seimbang oleh karena itu perlu diseimbangkan terlebih dahulu. Menyeimbangkan target ada 2 cara yaitu oversampling dan undersampling. oversampling dilakukan jika jumlah dataset sedikit sedangkan undersampling dilakukan jika jumlah data terlalu banyak.
# <br>
# Disini kita akan melakukan oversampling dikarenakan jumlah data kita tidak banyak. Salah satu metode yang Oversampling yang akan kita gunakan adalah SMOTE

# %%
from imblearn.over_sampling import SMOTE # Library untuk membantu oversampling dengan teknik SMOTE

# %%
smote = SMOTE(random_state=42) # Inisialisasi SMOTE
X_smote_resampled, y_smote_resampled = smote.fit_resample(X, y) # Mengaplikasikan oversampling pada dataset

# %%
plt.figure(figsize=(12, 4)) # Membuat sebuah figure (gambar) baru dengan ukuran 12x4 inci

new_df1 = pd.DataFrame(data=y) # Membuat DataFrame baru, new_df1

plt.subplot(1, 2, 1)
new_df1.value_counts().plot(kind='bar',figsize=(10,6),color=['#ac3664','#edce88'])
plt.title("infected before over sampling with SMOTE ")
plt.xticks(rotation=0);


plt.subplot(1, 2, 2) # Membuat subplot pertama dengan layout 1 baris dan 2 kolom
new_df2 = pd.DataFrame(data=y_smote_resampled)


new_df2.value_counts().plot(kind='bar',figsize=(10,6),color=['#ac3664','#edce88']) # Menghitung frekuensi masing-masing kategori (0 dan 1), membuat diagram batang (bar plot) berdasarkan frekuensi kategori
plt.title("infected after over sampling with SMOTE") # Memberikan judul pada subplot pertama
plt.xticks(rotation=0); # Menetapkan label sumbu-x (kategori 0 dan 1) untuk tetap dalam posisi horizontal

plt.tight_layout() # Mengatur layout agar subplot tidak saling tumpang tindih
plt.show() # Menampilkan kedua plot dalam satu figure

# %% [markdown]
# Lakukan pembagian data menjadi latih dan data testing

# %%
from sklearn.model_selection import train_test_split # Library untuk membantu memisahkan data menjadi dataset latih dan dataset validasi
X_train, X_test, y_train, y_test = train_test_split(X_smote_resampled, y_smote_resampled, test_size=0.2, random_state=42,stratify=y_smote_resampled) # 80% data latih, 20% data test

# %% [markdown]
# ## 8) Model <a class="anchor" id="h7"></a>

# %%
pip install dask[dataframe]
# Out:
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.11/dist-packages (2024.12.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.6.1)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2.2.2)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.1.21)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.17.0)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import precision_score, recall_score, f1_score

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
models = {
    'DecisionTree': DecisionTreeClassifier(random_state=42),
    'RandomForest': RandomForestClassifier(random_state=42),
    'LogisticRegression': LogisticRegression(max_iter=200),
    'GradientBoosting': GradientBoostingClassifier(random_state=42),
    'XGBoost': XGBClassifier(random_state=42),
    'LightGBM': LGBMClassifier(random_state=42)
}

def train_models(X_train, y_train, X_test, y_test):
    results = {}

    for model_name, model in models.items():

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_pred_proba = model.predict_proba(X_test)

        results[model_name] = {
            "model": model
        }

        # Output
        print(f"\n{model_name}")

        cm = confusion_matrix(y_test, y_pred)

        # Plot Confusion Matrix
        plt.figure(figsize=(4, 4))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[1, 2, 3], yticklabels=[1, 2, 3])
        plt.title(f"Confusion Matrix - {model_name}")
        plt.xlabel('Predicted Labels')
        plt.ylabel('True Labels')
        plt.show()

    return results

# Example usage:
results = train_models(X_train, y_train, X_test, y_test)
# Out:
# DecisionTree
# RandomForest
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression
# GradientBoosting
# XGBoost
# [LightGBM] [Info] Number of positive: 1294, number of negative: 1294
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000893 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1916
# [LightGBM] [Info] Number of data points in the train set: 2588, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#
# LightGBM

# %% [markdown]
# ## 9) Evaluasi <a class="anchor" id="h9"></a>

# %%
models = {
    'DecisionTree': DecisionTreeClassifier(random_state=42),
    'RandomForest': RandomForestClassifier(random_state=42),
    'LogisticRegression': LogisticRegression(max_iter=200),
    'GradientBoosting': GradientBoostingClassifier(random_state=42),
    'XGBoost': XGBClassifier(random_state=42),
    'LightGBM': LGBMClassifier(random_state=42)
}

def evaluation(X_train, y_train, X_test, y_test):
    results = {}

    for model_name, model in models.items():

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_pred_proba = model.predict_proba(X_test)

        # Accuracy
        accuracy = accuracy_score(y_test, y_pred)

        # Precision, Recall, F1-score
        precision = precision_score(y_test, y_pred, average='weighted')
        recall = recall_score(y_test, y_pred, average='weighted')
        f1 = f1_score(y_test, y_pred, average='weighted')


        results[model_name] = {
            "accuracy": accuracy,
            "model": model
        }

        # Classification Report
        print(f"\nClassification Report for {model_name}:\n")
        print(classification_report(y_test, y_pred))
        print("\n")

        # Output
        print(f"\n{model_name} - Metrics:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")

    return results

# Example usage:
results = evaluation(X_train, y_train, X_test, y_test)
# Out:
# Classification Report for DecisionTree:
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88       324
#            1       0.87      0.90      0.89       324
#
#     accuracy                           0.89       648
#    macro avg       0.89      0.89      0.89       648
# weighted avg       0.89      0.89      0.89       648
#
#
#
#
# DecisionTree - Metrics:
# Accuracy: 0.8858
# Precision: 0.8863
# Recall: 0.8858
# F1 Score: 0.8858
#
# Classification Report for RandomForest:
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94       324
#            1       0.93      0.94      0.94       324
#
#     accuracy                           0.94       648
#    macro avg       0.94      0.94      0.94       648
# weighted avg       0.94      0.94      0.94       648
#
#
#
#
# RandomForest - Metrics:
# Accuracy: 0.9367
# Precision: 0.9368
# Recall: 0.9367
# F1 Score: 0.9367
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Classification Report for LogisticRegression:
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       324
#            1       0.88      0.87      0.88       324
#
#     accuracy                           0.88       648
#    macro avg       0.88      0.88      0.88       648
# weighted avg       0.88      0.88      0.88       648
#
#
#
#
# LogisticRegression - Metrics:
# Accuracy: 0.8765
# Precision: 0.8766
# Recall: 0.8765
# F1 Score: 0.8765
#
# Classification Report for GradientBoosting:
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93       324
#            1       0.92      0.93      0.93       324
#
#     accuracy                           0.93       648
#    macro avg       0.93      0.93      0.93       648
# weighted avg       0.93      0.93      0.93       648
#
#
#
#
# GradientBoosting - Metrics:
# Accuracy: 0.9275
# Precision: 0.9275
# Recall: 0.9275
# F1 Score: 0.9275
#
# Classification Report for XGBoost:
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       324
#            1       0.93      0.95      0.94       324
#
#     accuracy                           0.94       648
#    macro avg       0.94      0.94      0.94       648
# weighted avg       0.94      0.94      0.94       648
#
#
#
#
# XGBoost - Metrics:
# Accuracy: 0.9383
# Precision: 0.9384
# Recall: 0.9383
# F1 Score: 0.9383
# [LightGBM] [Info] Number of positive: 1294, number of negative: 1294
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000669 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1916
# [LightGBM] [Info] Number of data points in the train set: 2588, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#
# Classification Report for LightGBM:
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       324
#            1       0.94      0.94      0.94       324
#
#     accuracy                           0.94       648
#    macro avg       0.94      0.94      0.94       648
# weighted avg       0.94      0.94      0.94       648
#
#
#
#
# LightGBM - Metrics:
# Accuracy: 0.9398
# Precision: 0.9398
# Recall: 0.9398
# F1 Score: 0.9398

# %%
# Ekstrak nama model dan nilai akurasi
model_names = list(results.keys())
accuracy_values = [metrics["accuracy"] * 100 for metrics in results.values()]  # Convert to percentages

# Membuat bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=model_names, y=accuracy_values, palette="rocket")

# Menambahkan labels and title
plt.title("Model Accuracy Comparison", fontsize=16)
plt.xlabel("Models", fontsize=12)
plt.ylabel("Accuracy (%)", fontsize=12)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.ylim(0, 100)  # Set y-axis limit to show percentages properly

# Menambahkan accuracy values di atas bar
for i, acc in enumerate(accuracy_values):
    plt.text(i, acc + 1, f"{acc:.2f}%", ha='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-103-96d2377e9ebd>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=model_names, y=accuracy_values, palette="rocket")

# %% [markdown]
# Hasil dari analisis ini memberikan wawasan mendalam tentang model mana yang paling efektif dalam menangani dataset yang digunakan. Model **LightGBM** menunjukkan akurasi tertinggi sebesar **93.98%**, menjadikannya model yang paling efektif untuk dataset ini. Selain LightGBM, model **Random Forest**, **XGBoost** dan **Gradient Boosting** juga menonjol dengan akurasi masing-masing 93.67%, 93.83%, 92.75%. Di sisi lain, model yang lebih sederhana seperti **DecisionTree** dan **LogisticRegression** mencatat akurasi yang lebih rendah, yaitu masing-masing 88.58% dan 87.65%.Akurasi ini menunjukkan bahwa kedua model tersebut mungkin kurang mampu menangani kompleksitas data dibandingkan model berbasis ensemble atau boosting. DecisionTree, meskipun intuitif dan mudah diinterpretasikan, cenderung mengalami overfitting pada data yang kompleks. Sementara itu, LogisticRegression, yang merupakan model linear, mungkin tidak cukup fleksibel untuk menangkap pola non-linear yang ada dalam dataset.
# Dengan kompleksitas dataset yang terus meningkat, model seperti LightGBM menjadi simbol adaptasi teknologi terhadap tantangan analisis data modern. Hal ini menggarisbawahi pentingnya inovasi dalam pemodelan, di mana kekuatan algoritma dapat dioptimalkan untuk menjawab kebutuhan analisis di masa depan.
